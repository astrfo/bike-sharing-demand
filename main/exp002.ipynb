# %% [markdown]
# # exp002

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_log_error
import lightgbm as lgb

sns.set_style("darkgrid")
# %matplotlib inline

# %% [markdown]
# ## データセットの読み込み

# %%
input_path = Path("../input")

train_df = pd.read_parquet(input_path / "train.parquet")
test_df = pd.read_parquet(input_path / "test.parquet")

# %% [markdown]
# ## RMSLEの定義

# %%
def feval_rmsle(preds, data):
    y_true = data.get_label()
    preds = np.clip(preds, 0, None)  # 0より小さい値を0に置換
    rmsle = np.sqrt(mean_squared_log_error(y_true, preds))
    return 'RMSLE', rmsle, False

# %% [markdown]
# ## train

# %%
def train(df, model_path):
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    fold_rmsles = []

    for fold, (train_index, valid_index) in enumerate(kf.split(df)):
        print(f"start training for fold {fold}")

        X_train = df.iloc[train_index].drop(["count", "datetime", "casual", "registered"], axis=1)
        y_train = df.iloc[train_index]["count"]

        X_valid = df.iloc[valid_index].drop(["count", "datetime", "casual", "registered"], axis=1)
        y_valid = df.iloc[valid_index]["count"]

        print("start training")
        params = {
            "objective": "regression",
            "seed": 42,
            "learning_rate": 0.05,
            "num_leaves": 32,
        }

        train_set = lgb.Dataset(X_train, y_train)
        valid_set = lgb.Dataset(X_valid, y_valid, reference=train_set)

        model = lgb.train(
            params=params,
            train_set=train_set,
            valid_sets=[train_set, valid_set],
            num_boost_round=10000,
            feval=feval_rmsle,
            callbacks=[
                lgb.early_stopping(stopping_rounds=10, verbose=True),
                lgb.log_evaluation(period=10)
            ]
        )

        print(f"predict valid for fold {fold}")
        y_pred = model.predict(X_valid)

        fold_rmsles.append(np.sqrt(mean_squared_log_error(y_valid, y_pred)))

        print(f"save model for fold {fold}")
        model.save_model(model_path / f"model_fold{fold+1:03d}.bin", num_iteration=model.best_iteration)

    return sum(fold_rmsles) / len(fold_rmsles)

# %%
model_path = Path("../output/model002")

train_rmsle = train(train_df, model_path)
print(f"RMSLE: {train_rmsle}")
# Out:
# start training for fold 0
# start training
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000053 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 227
# [LightGBM] [Info] Number of data points in the train set: 8708, number of used features: 8
# [LightGBM] [Info] Start training from score 191.584750
# Training until validation scores don't improve for 10 rounds
# [10]	training's l2: 25732	training's RMSLE: 1.46767	valid_1's l2: 26078.8	valid_1's RMSLE: 1.48843
# [20]	training's l2: 22854.5	training's RMSLE: 1.40697	valid_1's l2: 23320.1	valid_1's RMSLE: 1.42752
# [30]	training's l2: 21451.2	training's RMSLE: 1.36495	valid_1's l2: 22149.8	valid_1's RMSLE: 1.38776
# [40]	training's l2: 20626.7	training's RMSLE: 1.33564	valid_1's l2: 21576.2	valid_1's RMSLE: 1.36209
# [50]	training's l2: 20108.2	training's RMSLE: 1.31491	valid_1's l2: 21296.2	valid_1's RMSLE: 1.34471
# [60]	training's l2: 19738.3	training's RMSLE: 1.2992	valid_1's l2: 21161.8	valid_1's RMSLE: 1.33262
# [70]	training's l2: 19430.8	training's RMSLE: 1.28887	valid_1's l2: 21016.8	valid_1's RMSLE: 1.32417
# [80]	training's l2: 19187.3	training's RMSLE: 1.28036	valid_1's l2: 20940.2	valid_1's RMSLE: 1.31802
# [90]	training's l2: 18963	training's RMSLE: 1.27298	valid_1's l2: 20919.1	valid_1's RMSLE: 1.31359
# Early stopping, best iteration is:
# [87]	training's l2: 19029.7	training's RMSLE: 1.27528	valid_1's l2: 20917	valid_1's RMSLE: 1.31443
# predict valid for fold 0
# save model for fold 0
# start training for fold 1
# start training
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000048 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 229
# [LightGBM] [Info] Number of data points in the train set: 8709, number of used features: 8
# [LightGBM] [Info] Start training from score 192.251120
# Training until validation scores don't improve for 10 rounds
# [10]	training's l2: 25795.8	training's RMSLE: 1.47533	valid_1's l2: 25174.7	valid_1's RMSLE: 1.46202
# [20]	training's l2: 22822.7	training's RMSLE: 1.41266	valid_1's l2: 22790.9	valid_1's RMSLE: 1.40405
# [30]	training's l2: 21447.8	training's RMSLE: 1.3715	valid_1's l2: 21865.7	valid_1's RMSLE: 1.36696
# [40]	training's l2: 20664.4	training's RMSLE: 1.34287	valid_1's l2: 21413.3	valid_1's RMSLE: 1.34138
# [50]	training's l2: 20155.6	training's RMSLE: 1.32222	valid_1's l2: 21165.3	valid_1's RMSLE: 1.32371
# [60]	training's l2: 19804.4	training's RMSLE: 1.30779	valid_1's l2: 21055.5	valid_1's RMSLE: 1.31171
# [70]	training's l2: 19507.2	training's RMSLE: 1.29711	valid_1's l2: 21012.5	valid_1's RMSLE: 1.30311
# [80]	training's l2: 19230.4	training's RMSLE: 1.2882	valid_1's l2: 20934.4	valid_1's RMSLE: 1.29641
# [90]	training's l2: 18994.1	training's RMSLE: 1.28106	valid_1's l2: 20895.2	valid_1's RMSLE: 1.29126
# [100]	training's l2: 18816	training's RMSLE: 1.27603	valid_1's l2: 20888.1	valid_1's RMSLE: 1.288
# [110]	training's l2: 18637	training's RMSLE: 1.27105	valid_1's l2: 20870.5	valid_1's RMSLE: 1.2847
# [120]	training's l2: 18484.1	training's RMSLE: 1.2664	valid_1's l2: 20860.8	valid_1's RMSLE: 1.28189
# [130]	training's l2: 18340.5	training's RMSLE: 1.26242	valid_1's l2: 20847.6	valid_1's RMSLE: 1.27942
# [140]	training's l2: 18177	training's RMSLE: 1.25872	valid_1's l2: 20833.8	valid_1's RMSLE: 1.27739
# [150]	training's l2: 18027.8	training's RMSLE: 1.25508	valid_1's l2: 20807.4	valid_1's RMSLE: 1.27545
# [160]	training's l2: 17890.4	training's RMSLE: 1.25214	valid_1's l2: 20802.9	valid_1's RMSLE: 1.27398
# Early stopping, best iteration is:
# [158]	training's l2: 17911.6	training's RMSLE: 1.25235	valid_1's l2: 20796.2	valid_1's RMSLE: 1.27409
# predict valid for fold 1
# save model for fold 1
# start training for fold 2
# start training
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000114 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 229
# [LightGBM] [Info] Number of data points in the train set: 8709, number of used features: 8
# [LightGBM] [Info] Start training from score 192.640717
# Training until validation scores don't improve for 10 rounds
# [10]	training's l2: 25705.8	training's RMSLE: 1.46802	valid_1's l2: 26167.3	valid_1's RMSLE: 1.50088
# [20]	training's l2: 22813.3	training's RMSLE: 1.40629	valid_1's l2: 23311	valid_1's RMSLE: 1.44123
# [30]	training's l2: 21441.1	training's RMSLE: 1.36533	valid_1's l2: 22129.3	valid_1's RMSLE: 1.40278
# [40]	training's l2: 20629.6	training's RMSLE: 1.33681	valid_1's l2: 21572.3	valid_1's RMSLE: 1.37808
# [50]	training's l2: 20118.1	training's RMSLE: 1.3161	valid_1's l2: 21273.5	valid_1's RMSLE: 1.36075
# [60]	training's l2: 19735.3	training's RMSLE: 1.30229	valid_1's l2: 21172.6	valid_1's RMSLE: 1.35043
# [70]	training's l2: 19438.8	training's RMSLE: 1.29079	valid_1's l2: 21091.7	valid_1's RMSLE: 1.34203
# [80]	training's l2: 19177.7	training's RMSLE: 1.28136	valid_1's l2: 21052.2	valid_1's RMSLE: 1.33638
# [90]	training's l2: 18942	training's RMSLE: 1.27394	valid_1's l2: 20998.5	valid_1's RMSLE: 1.33226
# [100]	training's l2: 18732.1	training's RMSLE: 1.26819	valid_1's l2: 20986.3	valid_1's RMSLE: 1.32973
# [110]	training's l2: 18545.5	training's RMSLE: 1.26327	valid_1's l2: 20968.7	valid_1's RMSLE: 1.32715
# [120]	training's l2: 18386.1	training's RMSLE: 1.25847	valid_1's l2: 20963.1	valid_1's RMSLE: 1.32551
# [130]	training's l2: 18225.1	training's RMSLE: 1.2547	valid_1's l2: 20931.3	valid_1's RMSLE: 1.32384
# [140]	training's l2: 18090.4	training's RMSLE: 1.2512	valid_1's l2: 20923.7	valid_1's RMSLE: 1.32231
# Early stopping, best iteration is:
# [137]	training's l2: 18130.8	training's RMSLE: 1.25238	valid_1's l2: 20914.4	valid_1's RMSLE: 1.32259
# predict valid for fold 2
# save model for fold 2
# start training for fold 3
# start training
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000044 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 229
# [LightGBM] [Info] Number of data points in the train set: 8709, number of used features: 8
# [LightGBM] [Info] Start training from score 189.636927
# Training until validation scores don't improve for 10 rounds
# [10]	training's l2: 25361.9	training's RMSLE: 1.481	valid_1's l2: 27339	valid_1's RMSLE: 1.40649
# [20]	training's l2: 22398.9	training's RMSLE: 1.41832	valid_1's l2: 24863.1	valid_1's RMSLE: 1.34978
# [30]	training's l2: 21002.8	training's RMSLE: 1.37626	valid_1's l2: 23802.3	valid_1's RMSLE: 1.31136
# [40]	training's l2: 20213.9	training's RMSLE: 1.3483	valid_1's l2: 23358.2	valid_1's RMSLE: 1.28742
# [50]	training's l2: 19697.4	training's RMSLE: 1.3276	valid_1's l2: 23108.9	valid_1's RMSLE: 1.27003
# [60]	training's l2: 19316.9	training's RMSLE: 1.31302	valid_1's l2: 22999.9	valid_1's RMSLE: 1.2589
# [70]	training's l2: 19000.3	training's RMSLE: 1.30179	valid_1's l2: 22904.4	valid_1's RMSLE: 1.24985
# [80]	training's l2: 18739.3	training's RMSLE: 1.29432	valid_1's l2: 22836.4	valid_1's RMSLE: 1.24414
# [90]	training's l2: 18528.8	training's RMSLE: 1.28798	valid_1's l2: 22809.7	valid_1's RMSLE: 1.24056
# [100]	training's l2: 18337.8	training's RMSLE: 1.28223	valid_1's l2: 22791.4	valid_1's RMSLE: 1.2373
# [110]	training's l2: 18161.1	training's RMSLE: 1.27647	valid_1's l2: 22757.9	valid_1's RMSLE: 1.23384
# [120]	training's l2: 17988.6	training's RMSLE: 1.27246	valid_1's l2: 22719.9	valid_1's RMSLE: 1.23133
# [130]	training's l2: 17843.7	training's RMSLE: 1.26804	valid_1's l2: 22665.7	valid_1's RMSLE: 1.22812
# [140]	training's l2: 17702.9	training's RMSLE: 1.26424	valid_1's l2: 22631.5	valid_1's RMSLE: 1.22568
# [150]	training's l2: 17547.5	training's RMSLE: 1.2612	valid_1's l2: 22621.3	valid_1's RMSLE: 1.2243
# [160]	training's l2: 17407.4	training's RMSLE: 1.25847	valid_1's l2: 22585.3	valid_1's RMSLE: 1.22298
# [170]	training's l2: 17283.7	training's RMSLE: 1.25582	valid_1's l2: 22564.9	valid_1's RMSLE: 1.22181
# [180]	training's l2: 17158.6	training's RMSLE: 1.25272	valid_1's l2: 22539	valid_1's RMSLE: 1.22068
# [190]	training's l2: 17035.1	training's RMSLE: 1.24938	valid_1's l2: 22517.9	valid_1's RMSLE: 1.21946
# [200]	training's l2: 16892.3	training's RMSLE: 1.24632	valid_1's l2: 22502.7	valid_1's RMSLE: 1.21792
# Early stopping, best iteration is:
# [199]	training's l2: 16910.2	training's RMSLE: 1.24642	valid_1's l2: 22500.6	valid_1's RMSLE: 1.21799
# predict valid for fold 3
# save model for fold 3
# start training for fold 4
# start training
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000068 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 227
# [LightGBM] [Info] Number of data points in the train set: 8709, number of used features: 8
# [LightGBM] [Info] Start training from score 191.757148
# Training until validation scores don't improve for 10 rounds
# [10]	training's l2: 25774.9	training's RMSLE: 1.46183	valid_1's l2: 25560.1	valid_1's RMSLE: 1.51277
# [20]	training's l2: 22862.2	training's RMSLE: 1.40067	valid_1's l2: 22995.4	valid_1's RMSLE: 1.45599
# [30]	training's l2: 21515	training's RMSLE: 1.35892	valid_1's l2: 21890.6	valid_1's RMSLE: 1.41747
# [40]	training's l2: 20706.6	training's RMSLE: 1.33107	valid_1's l2: 21320.8	valid_1's RMSLE: 1.3926
# [50]	training's l2: 20173.4	training's RMSLE: 1.31074	valid_1's l2: 21027.6	valid_1's RMSLE: 1.37512
# [60]	training's l2: 19776.4	training's RMSLE: 1.29699	valid_1's l2: 20836.6	valid_1's RMSLE: 1.36316
# [70]	training's l2: 19479.6	training's RMSLE: 1.28633	valid_1's l2: 20718.9	valid_1's RMSLE: 1.35455
# [80]	training's l2: 19221.9	training's RMSLE: 1.27816	valid_1's l2: 20651.5	valid_1's RMSLE: 1.34868
# [90]	training's l2: 18996.7	training's RMSLE: 1.27053	valid_1's l2: 20597.6	valid_1's RMSLE: 1.34412
# [100]	training's l2: 18791.8	training's RMSLE: 1.26452	valid_1's l2: 20549.2	valid_1's RMSLE: 1.34026
# [110]	training's l2: 18604.7	training's RMSLE: 1.25937	valid_1's l2: 20495.4	valid_1's RMSLE: 1.33693
# [120]	training's l2: 18446.3	training's RMSLE: 1.2555	valid_1's l2: 20494.2	valid_1's RMSLE: 1.33508
# Early stopping, best iteration is:
# [112]	training's l2: 18574.1	training's RMSLE: 1.2586	valid_1's l2: 20492.1	valid_1's RMSLE: 1.33654
# predict valid for fold 4
# save model for fold 4
# RMSLE: 1.2931299603117299

# %% [markdown]
# ## evaluate

# %%
def evaluate(df, model_path):
    predictions = []

    for fold in range(5):
        print(f"loading model for fold {fold}")
        model = lgb.Booster(model_file=model_path / f"model_fold{fold+1:03d}.bin")

        print(f"start evaluate for fold {fold}")
        X_test = df.drop(["datetime"], axis=1)

        print(f"predict test for fold {fold}")
        y_pred = model.predict(X_test, num_iteration=model.best_iteration)
        predictions.append(y_pred)
    
    average_predictions = np.mean(predictions, axis=0)
    return average_predictions

# %%
y_pred = evaluate(test_df, model_path)
y_pred
# Out:
# loading model for fold 0
# start evaluate for fold 0
# predict test for fold 0
# loading model for fold 1
# start evaluate for fold 1
# predict test for fold 1
# loading model for fold 2
# start evaluate for fold 2
# predict test for fold 2
# loading model for fold 3
# start evaluate for fold 3
# predict test for fold 3
# loading model for fold 4
# start evaluate for fold 4
# predict test for fold 4
# array([111.9512672 ,  72.12340128,  72.12340128, ...,  94.42352578,
#         89.32561831,  80.54186058])

# %%
submission = pd.read_csv(input_path / "sampleSubmission.csv")
submission["count"] = y_pred
submission.to_csv("../output/submission002.csv", index=False)

# %% [markdown]
# ## Result

# %%
model = lgb.Booster(model_file=model_path / f"model_fold001.bin")
importance_df = pd.DataFrame()

importance_df["importance"] = model.feature_importance(importance_type="gain")
importance_df["feature_name"] = model.feature_name()
importance_df = importance_df.sort_values("importance", ascending=False)

fig = plt.figure(figsize=(5, 10))
sns.barplot(data=importance_df, x="importance", y="feature_name")
plt.show()
